# %%
from joblib import Parallel, delayed
from tqdm.auto import tqdm
from functools import wraps

# %%
def return_with_arguments(func):
    @wraps(func)
    def wrapper(*args, **kwargs):
        return func(*args, **kwargs), args, kwargs
    return wrapper
